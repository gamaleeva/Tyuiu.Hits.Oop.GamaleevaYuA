// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания № 3

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс Employee в C#, который будет представлять информацию о
// сотрудниках компании. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
// Требования к базовому классу Employee:
// • Атрибуты: Имя (Name), Возраст (Age), Зарплата (Salary).
// • Методы:
// o GetInfo(): метод для получения информации о сотруднике в виде
// строки.
// o Work(): метод для вывода сообщения о выполнении рабочих
// обязанностей.
// o TakeVacation(): метод для вывода сообщения о взятии отпуска.
// Требования к производным классам:
// 1. Менеджер (Manager): Должен содержать дополнительные атрибуты, такие
// как Количество подчиненных (SubordinatesCount). Метод Work() должен быть
// переопределен для добавления информации о управлении командой.
// 2. Разработчик (Developer): Должен содержать дополнительные атрибуты,
// такие как Специализация (Specialization). Метод TakeVacation() должен быть
// переопределен для добавления информации о необходимости согласования
// отпуска с проектными сроками.
// 3. Дизайнер (Designer) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Стиль дизайна (DesignStyle).
// Метод Work() должен быть переопределен для добавления информации о
// работе над дизайн-проектами.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public interface IInforAboutEmployee
{
    public void GetInfo();
}
public interface IWorkable
{
    public void Work();
}
public interface IVacationable
{
    public void TakeVacation();
}
public class Employee : IInforAboutEmployee, IWorkable, IVacationable
{
   

    private string name;
    private int age;
    private int salary;
    protected string Name
    {
        get {return name;}
        set {name = value;}
    }
    protected int Age
    {
        get {return age;}
        set {if (value > 14) age = value;
        else Console.WriteLine("Возраст сотрудника не может быть меньше 14 лет");}
    }
    protected int Salary
    {
        get {return salary;}
        set {salary = value;}
    }
    public Employee(string name, int age)
    {
        Name = name;
        Age = age;
        Salary = 27000;
        TotalEmployees++;
    }
    public void RaiseASalary(int money)
    {
        Salary += money;
        Console.WriteLine($"Зарплата сотрудника {Name} теперь составляет {Salary}!");
    }
    public void GetInfo()
    {
        Console.WriteLine($"Имя сотрудника: {Name}. Возраст: {Age}. Зарплата: {Salary}");
    }
    public virtual void Work()
    {
        Console.WriteLine($"{Name} выполняет рабочие обязанности");
    }
    public virtual void TakeVacation()
    {
        Console.WriteLine($"{Name} взял отпуск !");
    }
    public static int TotalEmployees {get; private set;} = 0;
    public static void DisplayTotalEmployees()
    {
        Console.WriteLine($"Коричество сотрудников: {TotalEmployees}");
    }
}
public class Manager : Employee
{
    public Manager(string name, int age) : base(name, age)
    {
        Name = name;
        Age = age;
        Salary = 27000;
    }
    
    private string subordinatescount;
    public string SubordinatesCount
    {
        get {return subordinatescount;}
        set {subordinatescount = value;}
    }
    public override void Work()
    {
        Console.WriteLine($"{Name} управляет командой из {SubordinatesCount} человек");
    }
}
public class Developer : Employee
{
    public Developer(string name, int age) : base (name, age)
    {
        Name = name;
        Age = age;
        Salary = 27000;
    }
    private string specialization;
    public string Specialization
    {
        get {return specialization;}
        set {specialization = value;}
    }
    public override void TakeVacation()
    {
        Console.WriteLine($"Разработчику {Name} со специализацией {Specialization} требуется согласовать отпуск с проектными сроками");
    }
}
public class Designer : Employee
{
    public Designer(string name, int age) : base(name, age)
    {
        Name = name;
        Age = age;
        Salary = 27000;
    }
    private string designstyle;
    public string DesignStyle
    {
        get {return designstyle;}
        set {designstyle = value;}
    }
    public override void Work()
    {
        Console.WriteLine($"{Name} работает над дизайн проектами в стиле {DesignStyle}");
    }
}
Employee Elsa = new Employee("Эльза", 21);
Elsa.GetInfo();
Elsa.Work();
Elsa.TakeVacation();
Console.WriteLine("-------------------------------------------");
Manager Kirk = new Manager("Кирк", 42);
Kirk.SubordinatesCount = "5";
Kirk.GetInfo();
Kirk.Work();
Kirk.TakeVacation();
Kirk.RaiseASalary(30000);
Console.WriteLine("-------------------------------------------");
Developer Julia =new Developer("Джулия", 24);
Julia.Specialization = "Junior";
Julia.GetInfo();
Julia.Work();
Julia.TakeVacation();
Julia.RaiseASalary(30000);
Console.WriteLine("-------------------------------------------");
Designer Kirill = new Designer("Кирилл", 30);
Kirill.DesignStyle = "Минимализм";
Kirill.GetInfo();
Kirill.Work();
Kirill.TakeVacation();
Console.WriteLine("-------------------------------------------");
Employee.DisplayTotalEmployees();
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-$CACHE_BUSTER$' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://fdfd::1a6b:95b:2050/","http://fe80::b961:7631:fde9:fa13%7:2050/","http://26.107.9.91:2050/","http://fe80::65a3:4198:3402:3ccd%13:2050/","http://192.168.0.106:2050/","http://::1:2050/","http://127.0.0.1:2050/","http://2001:0:14c9:d804:1c70:d9e3:268b:c55b:2050/","http://fe80::1c70:d9e3:268b:c55b%12:2050/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '18404.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// Имя сотрудника: Эльза. Возраст: 21. Зарплата: 27000
// Эльза выполняет рабочие обязанности
// Эльза взял отпуск !
// -------------------------------------------
// Имя сотрудника: Кирк. Возраст: 42. Зарплата: 27000
// Кирк управляет командой из 5 человек
// Кирк взял отпуск !
// Зарплата сотрудника Кирк теперь составляет 57000!
// -------------------------------------------
// Имя сотрудника: Джулия. Возраст: 24. Зарплата: 27000
// Джулия выполняет рабочие обязанности
// Разработчику Джулия со специализацией Junior требуется согласовать отпуск с проектными сроками
// Зарплата сотрудника Джулия теперь составляет 57000!
// -------------------------------------------
// Имя сотрудника: Кирилл. Возраст: 30. Зарплата: 27000
// Кирилл работает над дизайн проектами в стиле Минимализм
// Кирилл взял отпуск !
// -------------------------------------------
// Коричество сотрудников: 4
